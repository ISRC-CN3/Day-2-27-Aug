# %% [markdown]
# ### Loading the modules, initialising the weights, loading the data

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# initialise weight matrix
num_neurons = 784
W = np.zeros([num_neurons,num_neurons])

# load data
train_images=np.genfromtxt('train_images.csv',delimiter=',')
test_images=np.genfromtxt('test_images.csv',delimiter=',')

# %% [markdown]
# ### Visualising the input patterns (training data)

# %%
# train image 0  T-shirt
x = np.copy(train_images[0])
plt.imshow(np.reshape(x,(28,28)))
plt.show()
# train image 1  Dress
x = np.copy(train_images[1])
plt.imshow(np.reshape(x,(28,28)))
plt.show()
# train image 2   Shoes
x = np.copy(train_images[2])
plt.imshow(np.reshape(x,(28,28)))
plt.show()

# %% [markdown]
# ### Setting the weights (training the network)

# %%
# set weights from training images
for i in range(num_neurons):
    for j in range(num_neurons):
        for k in range(3):
            W[i,j] += 0.33333*train_images[k][i]*train_images[k][j]
for i in range(num_neurons):
    W[i,i] = 0

# %% [markdown]
# ### Defining the dynamics of the model (the state update rule)

# %%
# function for updating state asynchronously
def updateState(x):
    ind = random.choice(range(784))
    total_input = np.dot(W[ind,:],x)                               
    if total_input>=0:
        x[ind] = 1
    else:
        x[ind] = -1          
    return x

# %% [markdown]
# ### Observing convergence to the learned images from different initial conditions (long-sleeve shirt and a random pattern)

# %%
# test image 0
x = np.copy(test_images[0]) # long-sleeve shirt
plt.imshow(np.reshape(x,(28,28)))
plt.show()
for t in range(1000):
    x = updateState(x)
plt.imshow(np.reshape(x,(28,28)))
plt.show()
for t in range(2000):
    x = updateState(x)
plt.imshow(np.reshape(x,(28,28)))
plt.show()

# %%
# test image 1
x = np.copy(test_images[1]) # random pattern
plt.imshow(np.reshape(x,(28,28)))
plt.show()
for t in range(1000):
    x = updateState(x)
plt.imshow(np.reshape(x,(28,28)))
plt.show()
for t in range(2000):
    x = updateState(x)
plt.imshow(np.reshape(x,(28,28)))
plt.show()
